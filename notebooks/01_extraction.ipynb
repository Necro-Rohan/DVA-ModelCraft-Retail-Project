# %% [markdown]
# # 01 Extraction
#
# Use this notebook to load the raw dataset, inspect its structure, and confirm that the source is suitable for the project.

# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().resolve().name == 'notebooks' else Path.cwd().resolve()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 from pathlib import Path
# ----> 3 import pandas as pd
#       5 PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().resolve().name == 'notebooks' else Path.cwd().resolve()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
RAW_PATH = PROJECT_ROOT / 'data/raw/RTA_Dataset.csv'
df = pd.read_csv(RAW_PATH)
df.head()

# %%
print('Rows:', len(df))
print('Columns:', len(df.columns))
df.info()
